# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriarshimul/LSTM/blob/main/lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM ,  Dense

# %%
# Generating sample time-series data

# Generating sample time-series data

np.random.seed(42)
time = np.linspace(0, 100, 1000)
sin_wave = np.sin(time)+0.1 * np.random.normal(size=len(time))

# %%
# visualizing the time-series data
plt.plot(time, sin_wave)
plt.title('Sample Time-series Data')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()
